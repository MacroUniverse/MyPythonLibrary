# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
A = np.linspace(0,5,30) 
B = np.sin(A)
C = np.exp(-A)
plt.plot(A,B)
plt.plot(A,C)
plt.savefig("test.svg")

# %%
os.getcwd()
# Out:
# '/mnt/c/Users/addis/Desktop'
